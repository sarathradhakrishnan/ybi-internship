# %% [markdown]
# ### **Bike Price Prediction using Linear Regression**

# %% [markdown]
# **Import Library**

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# **Import CSV as DataFrame**

# %%
df = pd.read_csv(r'https://github.com/YBI-Foundation/Dataset/raw/main/Bike%20Prices.csv')

# %% [markdown]
# **Get the First Five Rows of DataFrame**

# %%
df.head()
# Out:
#    Brand               Model  Selling_Price  Year Seller_Type      Owner  \
# 0    TVS          TVS XL 100          30000  2017  Individual  1st owner
# 1  Bajaj       Bajaj  ct 100          18000  2017  Individual  1st owner
# 2     Yo            Yo Style          20000  2011  Individual  1st owner
# 3  Bajaj  Bajaj Discover 100          25000  2010  Individual  1st owner
# 4  Bajaj  Bajaj Discover 100          24999  2012  Individual  2nd owner
#
#    KM_Driven  Ex_Showroom_Price
# 0       8000            30490.0
# 1      35000            32000.0
# 2      10000            37675.0
# 3      43000            42859.0
# 4      35000            42859.0

# %% [markdown]
# **Get Information of DataFrame**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061 entries, 0 to 1060
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Brand              1061 non-null   object
#  1   Model              1061 non-null   object
#  2   Selling_Price      1061 non-null   int64
#  3   Year               1061 non-null   int64
#  4   Seller_Type        1061 non-null   object
#  5   Owner              1061 non-null   object
#  6   KM_Driven          1061 non-null   int64
#  7   Ex_Showroom_Price  626 non-null    float64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 66.4+ KB

# %% [markdown]
# **Get Missing Values Drop**

# %%
df = df.dropna()

# %% [markdown]
# **Get Summary Statistics**

# %%
df.describe()
# Out:
#        Selling_Price         Year      KM_Driven  Ex_Showroom_Price
# count     626.000000   626.000000     626.000000       6.260000e+02
# mean    59445.164537  2014.800319   32671.576677       8.795871e+04
# std     59904.350888     3.018885   45479.661039       7.749659e+04
# min      6000.000000  2001.000000     380.000000       3.049000e+04
# 25%     30000.000000  2013.000000   13031.250000       5.485200e+04
# 50%     45000.000000  2015.000000   25000.000000       7.275250e+04
# 75%     65000.000000  2017.000000   40000.000000       8.703150e+04
# max    760000.000000  2020.000000  585659.000000       1.278000e+06

# %% [markdown]
# **Get Categories and Counts of Categorical Variables**

# %%
df[['Brand']].value_counts()
# Out:
# Brand
# Honda       170
# Bajaj       143
# Hero        108
# Yamaha       94
# Royal        40
# TVS          23
# Suzuki       18
# KTM           6
# Mahindra      6
# Kawasaki      4
# UM            3
# Activa        3
# Harley        2
# Vespa         2
# BMW           1
# Hyosung       1
# Benelli       1
# Yo            1
# dtype: int64

# %%
df[['Model']].value_counts()
# Out:
# Model
# Honda Activa [2000-2015]                      23
# Honda CB Hornet 160R                          22
# Bajaj Pulsar 180                              20
# Yamaha FZ S V 2.0                             16
# Bajaj Discover 125                            16
#                                               ..
# Royal Enfield Thunderbird 500                  1
# Royal Enfield Continental GT [2013 - 2018]     1
# Royal Enfield Classic Stealth Black            1
# Royal Enfield Classic Squadron Blue            1
# Yo Style                                       1
# Length: 183, dtype: int64

# %%
df[['Seller_Type']].value_counts()
# Out:
# Seller_Type
# Individual     623
# Dealer           3
# dtype: int64

# %%
df[['Owner']].value_counts()
# Out:
# Owner
# 1st owner    556
# 2nd owner     66
# 3rd owner      3
# 4th owner      1
# dtype: int64

# %% [markdown]
# **Get Column Names**

# %%
df.columns
# Out:
# Index(['Brand', 'Model', 'Selling_Price', 'Year', 'Seller_Type', 'Owner',
#        'KM_Driven', 'Ex_Showroom_Price'],
#       dtype='object')

# %% [markdown]
# **Get Shape of DataFrame**

# %%
df.shape
# Out:
# (626, 8)

# %% [markdown]
# **Get Encoding of Categorical Features**

# %%
df.replace({'Seller_Type':{'Individual':0,'Dealer':1}},inplace=True)

# %%
df.replace({'Owner':{'1st owner':0, '2nd owner':1,'3rd owner':2,'4th owner':3}},inplace=True)

# %% [markdown]
# **Define y(dependent or label or target varaible) and X(independent or features or attribute Variable)**

# %%
y=df['Selling_Price']

# %%
y.shape
# Out:
# (626,)

# %%
y
# Out:
# 0       30000
# 1       18000
# 2       20000
# 3       25000
# 4       24999
#         ...
# 621    330000
# 622    300000
# 623    425000
# 624    760000
# 625    750000
# Name: Selling_Price, Length: 626, dtype: int64

# %%
X=df[['Year','Seller_Type', 'Owner', 'KM_Driven', 'Ex_Showroom_Price']]

# %%
X.shape
# Out:
# (626, 5)

# %%
X
# Out:
#      Year  Seller_Type  Owner  KM_Driven  Ex_Showroom_Price
# 0    2017            0      0       8000            30490.0
# 1    2017            0      0      35000            32000.0
# 2    2011            0      0      10000            37675.0
# 3    2010            0      0      43000            42859.0
# 4    2012            0      1      35000            42859.0
# ..    ...          ...    ...        ...                ...
# 621  2014            0      3       6500           534000.0
# 622  2011            0      0      12000           589000.0
# 623  2017            0      1      13600           599000.0
# 624  2019            0      0       2800           752020.0
# 625  2013            0      1      12000          1278000.0
#
# [626 rows x 5 columns]

# %% [markdown]
# **Get Train Test Split**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, y_train,y_test = train_test_split(X,y,test_size =0.3, random_state =192529)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((438, 5), (188, 5), (438,), (188,))

# %% [markdown]
# **Get Model Train**

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **Get Model Prediction**

# %%
y_pred = lr.predict(X_test)

# %%
y_pred.shape
# Out:
# (188,)

# %%
y_pred
# Out:
# array([ 46627.16991375, 126226.52020448, 126915.34894874,  67354.80411471,
#         14813.39930475,  46839.77885267,  85518.32075127,  53095.29232364,
#         68127.8576971 ,  28587.77796485,  79050.70224517,  52211.98399093,
#         35813.00924905,  73478.03413024, 101053.55171226,  58783.45424363,
#         44251.72335479,  57618.47127661,  49530.81653207,    969.06834794,
#         12470.37423744,  50015.50196133,  79981.17843472,  60819.88960926,
#        127121.55648633,  45090.42775637,  27534.41258464,  25745.6814626 ,
#         54519.38187872,  12568.22768643,  67610.61101208,  53287.27853583,
#         61541.0989833 , 132020.17533751,  56950.50773661,  13575.73029004,
#         54163.62571074,  18486.4499815 ,  51586.64526728,  32456.18432149,
#         46448.21480677,  64333.32340921,  34925.23777441,  20065.24364098,
#         59695.55069931,  52721.21962316,  28345.76474148,  50505.89612141,
#         64199.69905282, 111793.12449683,  53214.8045307 ,  29488.96481307,
#         12312.99306953, 116764.90025149, -14922.86819707,  68776.78109846,
#        129582.52986166,  93917.77328887,  42249.82330108,  70333.5743356 ,
#         38210.24056896,  29861.88280602,  91299.11120425,  51319.72350635,
#         86298.41875577,  49207.4165874 ,   5912.08066817,  68159.19163464,
#         71475.99908412,  30334.08982783,  44974.285286  ,  36412.97321146,
#         34143.89934793,  42324.65138926, -10632.90186026, 110985.04623329,
#         20730.95378936,  61341.94921921,  73748.98006288,  41465.14928216,
#         79933.03496072,  29752.66079113,  56061.90888379,  20831.6278792 ,
#         33174.48277238,  13161.54772583,  15499.12508296,  25442.00290368,
#         59000.78959176,  39033.86867201,  55650.5284765 ,  44545.47710646,
#         86549.76565389,  50362.38325244,  61645.87788221,  57682.74729276,
#         49089.70483009,  55197.00324764,  42524.09258018,  42903.33410504,
#         87694.27435621,  50722.64768965,  52629.10407423,  47743.29584335,
#         70666.64114216, -10109.14704393,  23615.12346206,  38498.76924406,
#         69109.24788148,  28659.35530897,  50532.69715961, 124664.94562643,
#         85561.42351447,  24198.79024328,  64006.31776016,  37623.60559246,
#        251113.02358872,  20442.84624234,  49711.12221734,  53831.96582844,
#         55597.62963075,  12220.00009217,  49282.47357688,  48283.6646865 ,
#         54225.49940235, 100714.57273074,  -4633.40351981,  77831.32730993,
#         71668.00230202,  37118.89420051,  59500.60865664,  34629.39033318,
#         61342.43902334,   5226.35488997,  64172.97539076,  52935.38678989,
#         60064.82886703,  58265.32264761, 134410.31457909,  19262.72948492,
#         43582.06949512,  48645.88318162,  40594.36629617,  40641.96447151,
#         66778.90458029,  68040.52989292,  51160.30006987,  58411.87699207,
#         30245.56859102,  62258.58230197, 155392.54450546,  29226.5288807 ,
#         50111.36916965,  93915.81407236, 106231.83047716,  51369.89369905,
#         54191.18307341,  60677.0056697 ,  44737.24262284,  69370.13116489,
#         59002.48216469,  51963.97748237,  35284.46240117,  33694.67837773,
#        132422.84325462,  56624.38010778,  49149.46541902,  -4386.71724174,
#         70443.84219799,  30861.03792319,  55824.30235358,  44182.79428308,
#         56317.91526755,  53444.17653974,  39462.32689067,  51547.4609371 ,
#         33673.76492141,   -585.59033778,  90853.84336772,  36424.46125818,
#         36730.01160771, 101407.14680531,  51652.4895268 ,   1072.09526361,
#         25192.01308148,  51560.70361052, 253396.34251396,  30530.69690335])

# %% [markdown]
# **Get Model Evaluation**

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 174132867.80947834

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 9591.282995478627

# %%
r2_score(y_test, y_pred)
# Out:
# 0.8967333034112704

# %% [markdown]
# **Get Visualization of Actual Vs Predicted Results**

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred)
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Actual Price vs Predicted Price')
plt.show()

# %% [markdown]
# **Get Future Predictions**

# %%
df_new = df.sample(1)

# %%
df_new
# Out:
#      Brand                                Model  Selling_Price  Year  \
# 567  Royal  Royal Enfield Classic Gunmetal Grey         140000  2018
#
#      Seller_Type  Owner  KM_Driven  Ex_Showroom_Price
# 567            0      0      22000           148114.0

# %%
df_new.shape
# Out:
# (1, 8)

# %%
X_new = df_new.drop(['Brand', 'Model', 'Selling_Price'],axis = 1)

# %%
y_pred_new = lr.predict(X_new)

# %%
y_pred_new
# Out:
# array([116453.38482654])
